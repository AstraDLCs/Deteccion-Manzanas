# %%
import ultralytics
from ultralytics import YOLO
import torch    
import cv2
import numpy as np
import matplotlib.pyplot as plt
import requests
import torchvision.transforms as transforms
from PIL import Image
import io
from yolo_cam.eigen_cam import GradMap
from yolo_cam.utils.image import show_cam_on_image, scale_cam_image
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [3.0, 3.0]

# %%
model = YOLO("./runs/detect/train/weights/best.pt")
model.cpu()
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
img_name = "./datasets/validate/images/478f9837-imagen_173.jpg"

# %%
for i in range(-20, -1):  
    img = cv2.imread(img_name) 
    img = cv2.resize(img, (640, 640))
    rgb_img = img.copy()
    img = np.float32(img) / 255

    target_layers = [model.model.model[i]]  
    cam = GradMap(model, target_layers, task='od')  
    grayscale_cam = cam(rgb_img)[0, :, :]  

    cam_image = show_cam_on_image(img, grayscale_cam, use_rgb=True)

    im = cv2.cvtColor(rgb_img, cv2.COLOR_RGB2BGR)

    combined_image = np.hstack((im, cam_image))

    filename = f'grad-cam-{i}.png'
    Image.fromarray(combined_image).save(filename)  
    print(f"Imagen guardada: {filename}")

    plt.imshow(combined_image)
    plt.axis('off')
    plt.show()
# Out:
# 0: 640x640 1 manzana daada, 2 manzana roja frescas, 135.4ms
# Speed: 4.0ms preprocess, 135.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Imagen guardada: grad-cam--20.png
# 0: 640x640 1 manzana daada, 2 manzana roja frescas, 126.9ms
# Speed: 4.0ms preprocess, 126.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Imagen guardada: grad-cam--19.png
# 0: 640x640 1 manzana daada, 2 manzana roja frescas, 129.9ms
# Speed: 2.5ms preprocess, 129.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Imagen guardada: grad-cam--18.png
# 0: 640x640 1 manzana daada, 2 manzana roja frescas, 123.7ms
# Speed: 2.5ms preprocess, 123.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Imagen guardada: grad-cam--17.png
# 0: 640x640 1 manzana daada, 2 manzana roja frescas, 129.7ms
# Speed: 2.6ms preprocess, 129.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Imagen guardada: grad-cam--16.png
# ...

# %%
results = model(img_name) 

for result in results:
    boxes = result.boxes
    masks = result.masks
    keypoints = result.keypoints
    probs = result.probs
    obb = result.obb
    result.show()
    result.save(filename="result.jpg")
# Out:
# image 1/1 c:\Users\nicko\Downloads\manzanas\datasets\validate\images\478f9837-imagen_173.jpg: 640x640 1 manzana daada, 2 manzana roja frescas, 126.8ms
# Speed: 3.0ms preprocess, 126.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
